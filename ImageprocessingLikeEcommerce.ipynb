# %%
from IPython.display import Image

# %%
Image(filename='indiagate.jpg')

# %%
from IPython.display import Image, display

# %%
listOfImageNames = ['tent1.jpg', 'tent2.jpg', 'tent3.jpg', 'tent6.jpg']

# %%
for i in listOfImageNames:
    display(Image(filename= i))

# %%
import ipyplot

# %%
ipyplot.plot_images(listOfImageNames, max_images=20, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-eHifqqQqWs45iqEmpfQKqE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eHifqqQqWs45iqEmpfQKqE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eHifqqQqWs45iqEmpfQKqE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eHifqqQqWs45iqEmpfQKqE:checked ~ #ipyplot-html-viewer-textarea-eHifqqQqWs45iqEmpfQKqE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eHifqqQqWs45iqEmpfQKqE:checked + #ipyplot-html-viewer-label-eHifqqQqWs45iqEmpfQKqE:after {
# ...

# %%
labels= ['Wildcraft', 'Aristocrat', 'VIP', 'American_Tourister']

# %%
ipyplot.plot_class_representations(listOfImageNames, labels, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-nCbPLSq5WsTMJ3LLCRQC3b {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nCbPLSq5WsTMJ3LLCRQC3b {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nCbPLSq5WsTMJ3LLCRQC3b {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nCbPLSq5WsTMJ3LLCRQC3b:checked ~ #ipyplot-html-viewer-textarea-nCbPLSq5WsTMJ3LLCRQC3b {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nCbPLSq5WsTMJ3LLCRQC3b:checked + #ipyplot-html-viewer-label-nCbPLSq5WsTMJ3LLCRQC3b:after {
# ...

# %%
product = ['Thor.jpg', 'Repsol.jpg', 'indiagate.jpg', 'Ladakh.jpg']

# %%
labels= ['Thor', 'Repsol', 'indiagate', 'Ladakh']

# %%
ipyplot.plot_class_tabs(product, labels, max_imgs_per_tab=5, img_width=250)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ND5ovhDcdwtAW8uYkQoiHL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ND5ovhDcdwtAW8uYkQoiHL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ND5ovhDcdwtAW8uYkQoiHL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ND5ovhDcdwtAW8uYkQoiHL:checked ~ #ipyplot-html-viewer-textarea-ND5ovhDcdwtAW8uYkQoiHL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ND5ovhDcdwtAW8uYkQoiHL:checked + #ipyplot-html-viewer-label-ND5ovhDcdwtAW8uYkQoiHL:after {
# ...
